# %%
import pandas as pd

# %%
#Define the csv file that we will be uploading
file_one = "big_data.csv"

# %%
#Uploading our csv file from google drive
gdrive_download_url = f'https://drive.google.com/uc?id={file_one}'

# %%
#First set of data: the data of a group of people coming from different countries
df_fileone = pd.read_csv(file_one)
df_fileone
# Out:
#      0 First Name  Gender        Country  Age        Date    id
# 0    1      Dulce  Female  United States   32  15/10/2017  1562
# 1    2       Mara  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip    Male         France   36  21/05/2015  2587
# 3    4   Kathleen  Female  United States   25  15/10/2017  3549
# 4    5    Nereida  Female  United States   58  16/08/2016  2468
# 5    6     Gaston    Male  United States   24  21/05/2015  2554
# 6    7       Etla  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza  Female  United States   40  21/05/2015  6548
# 9   10     Fallon  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia  Female  Great Britain   39  21/05/2015  1258
# 11  12   Franklyn    Male         France   38  15/10/2017  2579
# 12  13    Sherron  Female  Great Britain   32  16/08/2016  3256
# 13  14     Marcel    Male  Great Britain   26  21/05/2015  2587
# ...

# %%
#Changing the data into a set
first_names = df_fileone["First Name"]
first_names_set = set(first_names)
print(first_names_set)
# Out:
# {'Lauralee', 'Mara', 'Fallon', 'Cella', 'Angelyn', 'Shavonne', 'Teresa', 'Garth', 'Franklyn', 'Marcel', 'Shavon', 'Many', 'Lester', 'Loreta', 'Marvel', 'Nereida', 'Kathleen', 'Dulce', 'Holly', 'Vincenza', 'Arcelia', 'Sherron', 'Libbie', 'Etla', 'Francesca', 'Belinda', 'Gaston', 'Kina', 'Philip', 'Earlean'}

# %%
#Defining the second set of data
file_two = "babyNamesUSYOB-mostpopular.csv"

# %%
#Uploading the second set of csv file from Google Drive
gdrive_download_url = f'https://drive.google.com/uc?id={file_two}'

# %%
#Second set of data: 2023 Most Popular Baby Names from the 1800s 
df_filetwo = pd.read_csv(file_two)
df_filetwo
# Out:
#          index  YearOfBirth       Name Sex  Number
# 0            0         1880       Mary   F    7065
# 1            1         1880       Anna   F    2604
# 2            2         1880       Emma   F    2003
# 3            3         1880  Elizabeth   F    1939
# 4            4         1880     Minnie   F    1746
# ...        ...          ...        ...  ..     ...
# 224256  224256         2015      Marko   M     100
# 224257  224257         2015      Mauro   M     100
# 224258  224258         2015    Niklaus   M     100
# 224259  224259         2015     Osiris   M     100
# 224260  224260         2015     Steele   M     100
#
# [224261 rows x 5 columns]

# %%
#Changing the data into a set form
baby_names = df_filetwo["Name"]
baby_names_set = set(baby_names)
print(baby_names_set)
# Out:
# {'Nyomi', 'Dinah', 'Dontrell', 'Gerard', 'Taisha', 'Turner', 'Taniyah', 'Avi', 'Luke', 'Anika', 'Avary', 'Rickey', 'Jill', 'Angeles', 'Stacey', 'Josephine', 'Rachael', 'Melodee', 'Gissell', 'Alisa', 'Elnora', 'Jeremy', 'Susannah', 'Kellin', 'Dillion', 'Anakin', 'Sharita', 'Jonael', 'Arnav', 'Emberlyn', 'Xavior', 'Kimberley', 'Arya', 'Haylie', 'Shanita', 'Henri', 'Khushi', 'Kaylen', 'Lois', 'Genese', 'Buck', 'Leta', 'Devonte', 'Tenley', 'Niki', 'Niklaus', 'Matthias', 'Ishan', 'Ender', 'Jaylan', 'Duncan', 'Vivaan', 'Damoni', 'Suzie', 'Maude', 'Selene', 'Luis', 'Alexsandra', 'Hadlee', 'Kirby', 'Carlos', 'Eben', 'Guinevere', 'Gia', 'Rosanne', 'Christie', 'Caleigh', 'Jacalyn', 'Citlaly', 'Keila', 'Alexi', 'Jarren', 'Marquitta', 'Margarette', 'Will', 'Felisha', 'Tori', 'Perry', 'Batsheva', 'Kathy', 'Averie', 'Royce', 'Angelika', 'Yuridia', 'Janae', 'Brionna', 'Addalyn', 'Malena', 'Babyboy', 'Lynwood', 'Kadijah', 'Danyell', 'Carina', 'Franchesca', 'Dorla', 'Theron', 'Raekwon', 'Tkeyah', 'Me
# ...

# %%
#Finding the common names that appear in both data sets
#It shows the common names that 

print(baby_names_set & first_names_set)
# Out:
# {'Dulce', 'Marvel', 'Fallon', 'Francesca', 'Holly', 'Shavon', 'Marcel', 'Kathleen', 'Lester', 'Belinda', 'Shavonne', 'Garth', 'Mara', 'Sherron', 'Nereida', 'Vincenza', 'Franklyn', 'Teresa', 'Philip'}
